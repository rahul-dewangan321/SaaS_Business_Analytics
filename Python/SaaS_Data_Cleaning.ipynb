# %% [markdown]
# # 1. Import Libraries

# %%
import pandas as pd
import numpy as np

# %%
pd.set_option("display.max_columns", None)
pd.set_option("display.max_rows", 100)

# %% [markdown]
# # 2. Load Dataset

# %%
customers=pd.read_csv(r"D:\project\Saas DA\Dataset\Raw Datset\dim_customers.csv")

# %%
customers
# Out:
#       customer_id signup_date        country    industry company_size  \
# 0       CUST_2000  2025-09-15            NaN   Logistics      unknown
# 1       CUST_2001  2025-10-10            NaN  E-commerce         500+
# 2       CUST_2002  2025-03-19            NaN   Logistics      201-500
# 3      CUST_2003   2025-11-30            usa     Finance       51-200
# 4       CUST_2004  2025-01-30            NaN         NaN       51-200
# ...           ...         ...            ...         ...          ...
# 1545    CUST_2354  2025-05-13  United States  E-commerce        11-50
# 1546    CUST_2365  2025-08-05            NaN         NaN         1-10
# 1547    CUST_2309  2025-09-06             UK         NaN       51-200
# 1548    CUST_2736  2025-06-07         Canada         NaN      unknown
# 1549    CUST_2998  2025-02-12            NaN         NaN      201-500
#
#              segment
# 0                SMB
# 1         Enterprise
# 2     small business
# 3                SMB
# ...

# %%
plans=pd.read_csv(r"D:\project\Saas DA\Dataset\Raw Datset\dim_plans.csv")

# %%
plans
# Out:
#    plan_id   plan_name  monthly_price billing_cycle
# 0  p_basic       Basic           29.0       Monthly
# 1    p_pro         Pro           79.0       Monthly
# 2    p_ent  Enterprise          499.0        Annual

# %%
payments=pd.read_csv(r"D:\project\Saas DA\Dataset\Raw Datset\fact_payments.csv")

# %%
payments
# Out:
#       payment_id subscription_id payment_date  amount payment_status  \
# 0     PAY_500001       SUB_30000   2025-09-16   499.0       refunded
# 1     PAY_500002       SUB_30001   2025-10-13    79.0           paid
# 2     PAY_500003       SUB_30002   2025-03-24   499.0         failed
# 3     PAY_500004       SUB_30002   2025-04-23   499.0         failed
# 4     PAY_500005       SUB_30002   2025-05-21   499.0         failed
# ...          ...             ...          ...     ...            ...
# 3058  PAY_503059       SUB_31496   2025-08-22   499.0         failed
# 3059  PAY_503060       SUB_31496   2025-09-18   499.0           PAID
# 3060  PAY_503061       SUB_31497   2025-03-27    29.0       refunded
# 3061  PAY_503062       SUB_31498   2025-01-16    79.0         failed
# 3062  PAY_503063       SUB_31499   2025-02-11   499.0       refunded
#
#      payment_method
# 0       CREDIT_CARD
# 1            STRIPE
# 2               ACH
# 3            PAYPAL
# 4       CREDIT_CARD
# ...

# %%
subscriptions=pd.read_csv(r"D:\project\Saas DA\Dataset\SaaS raw Datset\fact_subscriptions.csv")

# %%
subscriptions
# Out:
#      subscription_id customer_id  plan_id  start_date    end_date       status
# 0          SUB_30000   CUST_2000    p_ent  2025-09-16         NaN          ACT
# 1          SUB_30001   CUST_2001   P_PRO   2025-10-10         NaN          ACT
# 2          SUB_30002   CUST_2002    p_ent  2025-03-21         NaN       active
# 3          SUB_30003   CUST_2003    p_ent  2025-12-02  2026-07-01     canceled
# 4          SUB_30004   CUST_2004    p_ent  2025-01-30         NaN       active
# ...              ...         ...      ...         ...         ...          ...
# 1495       SUB_31495   CUST_3495   P_PRO   2025-09-30         NaN          ACT
# 1496       SUB_31496   CUST_3496    p_ent  2025-07-20         NaN          ACT
# 1497       SUB_31497   CUST_3497  p_basic  2025-03-26  2025-11-11    cancelled
# 1498       SUB_31498   CUST_3498    p_pro  2025-01-15         NaN  active_plan
# 1499       SUB_31499   CUST_3499    p_ent  2025-02-09         NaN       active
#
# [1500 rows x 6 columns]

# %%
usage=pd.read_csv(r"D:\project\Saas DA\Dataset\Raw Datset\fact_usage.csv")

# %%
usage
# Out:
#          usage_id customer_id  event_date    feature_name  login_count  \
# 0      USG_700001   CUST_2000  2025-09-08  dashboard_view            8
# 1      USG_700002   CUST_2000  2025-05-11      export_csv            3
# 2      USG_700003   CUST_2000  2025-01-17      export_csv            3
# 3      USG_700004   CUST_2000  2025-03-10      export_csv            8
# 4      USG_700005   CUST_2000  2025-05-25      export_csv            3
# ...           ...         ...         ...             ...          ...
# 24751  USG_724752   CUST_2999  2025-01-20     team_invite            1
# 24752  USG_724753   CUST_2999  2025-01-14      export_csv            5
# 24753  USG_724754   CUST_2999  2025-05-20     team_invite            5
# 24754  USG_724755   CUST_2999  2025-10-25      export_csv           -8
# 24755  USG_724756   CUST_2999  2025-01-10    billing_edit            3
#
#        session_minutes
# 0               114.76
# 1                44.68
# 2                76.59
# ...

# %%
support = pd.read_csv(r"D:\project\Saas DA\Dataset\Raw Datset\fact_support.csv")

# %%
support
# Out:
#       ticket_id customer_id ticket_date  priority         category  \
# 0    TCK_900001   CUST_2006  2025-02-17      HIGH      Login Issue
# 1    TCK_900002   CUST_2006  2025-07-17       LOW         API Down
# 2    TCK_900003   CUST_2007  2025-08-23       LOW      Login Issue
# 3    TCK_900004   CUST_2008  2025-11-10    MEDIUM      Login Issue
# 4    TCK_900005   CUST_2008  2025-07-22    MEDIUM  Feature Request
# ..          ...         ...         ...       ...              ...
# 779  TCK_900780   CUST_3491  2025-07-02    MEDIUM  Feature Request
# 780  TCK_900781   CUST_3491  2025-03-02      HIGH         API Down
# 781  TCK_900782   CUST_3496  2025-04-09    MEDIUM  Feature Request
# 782  TCK_900783   CUST_3496  2025-08-07       LOW      Login Issue
# 783  TCK_900784   CUST_3496  2025-07-08  CRITICAL         API Down
#
#      resolution_time    status
# 0                 12    Closed
# 1                 41  resolved
# 2                 21    Closed
# 3                 43  resolved
# ...

# %% [markdown]
# # Customers Dataset

# %% [markdown]
# ## Data Inspection

# %%
customers
# Out:
#       customer_id signup_date        country    industry company_size  \
# 0       CUST_2000  2025-09-15            NaN   Logistics      unknown
# 1       CUST_2001  2025-10-10            NaN  E-commerce         500+
# 2       CUST_2002  2025-03-19            NaN   Logistics      201-500
# 3      CUST_2003   2025-11-30            usa     Finance       51-200
# 4       CUST_2004  2025-01-30            NaN         NaN       51-200
# ...           ...         ...            ...         ...          ...
# 1545    CUST_2354  2025-05-13  United States  E-commerce        11-50
# 1546    CUST_2365  2025-08-05            NaN         NaN         1-10
# 1547    CUST_2309  2025-09-06             UK         NaN       51-200
# 1548    CUST_2736  2025-06-07         Canada         NaN      unknown
# 1549    CUST_2998  2025-02-12            NaN         NaN      201-500
#
#              segment
# 0                SMB
# 1         Enterprise
# 2     small business
# 3                SMB
# ...

# %%
customers.head()
# Out:
#    customer_id signup_date country    industry company_size         segment
# 0    CUST_2000  2025-09-15     NaN   Logistics      unknown             SMB
# 1    CUST_2001  2025-10-10     NaN  E-commerce         500+      Enterprise
# 2    CUST_2002  2025-03-19     NaN   Logistics      201-500  small business
# 3   CUST_2003   2025-11-30     usa     Finance       51-200             SMB
# 4    CUST_2004  2025-01-30     NaN         NaN       51-200  small business

# %%
customers.tail()
# Out:
#      customer_id signup_date        country    industry company_size  \
# 1545   CUST_2354  2025-05-13  United States  E-commerce        11-50
# 1546   CUST_2365  2025-08-05            NaN         NaN         1-10
# 1547   CUST_2309  2025-09-06             UK         NaN       51-200
# 1548   CUST_2736  2025-06-07         Canada         NaN      unknown
# 1549   CUST_2998  2025-02-12            NaN         NaN      201-500
#
#              segment
# 1545  small business
# 1546  small business
# 1547             mid
# 1548             ENT
# 1549      Enterprise

# %%
customers.sample(10)
# Out:
#      customer_id signup_date         country    industry company_size  \
# 653    CUST_2653  2025-06-26              US   Logistics         1-10
# 29     CUST_2029  2025-11-23              US   Logistics       51-200
# 1520   CUST_3199  2025-11-05             usa         NaN      201-500
# 685    CUST_2685  2025-12-18              CA  E-commerce        11-50
# 725    CUST_2725  2025-01-20  united kingdom        SaaS       51-200
# 710    CUST_2710  2025-03-05          Canada   Logistics         500+
# 1284   CUST_3284  2025-09-24              US  Healthcare         1-10
# 67     CUST_2067  2025-09-10             NaN         NaN       51-200
# 989    CUST_2989  2025-11-24             NaN  E-commerce         500+
# 966    CUST_2966  2025-02-06   United States        SaaS       51-200
#
#          segment
# 653          SMB
# 29           ENT
# 1520         SMB
# 685          SMB
# 725   Enterprise
# 710   Mid-Market
# 1284  Enterprise
# 67           mid
# 989   Mid-Market
# ...

# %%
customers.shape
# Out:
# (1550, 6)

# %%
customers.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1550 entries, 0 to 1549
# Data columns (total 6 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   customer_id   1550 non-null   object
#  1   signup_date   1550 non-null   object
#  2   country       1202 non-null   object
#  3   industry      1305 non-null   object
#  4   company_size  1550 non-null   object
#  5   segment       1550 non-null   object
# dtypes: object(6)
# memory usage: 72.8+ KB

# %%
customers.describe(include="all")
# Out:
#        customer_id signup_date country industry company_size     segment
# count         1550        1550    1202     1305         1550        1550
# unique        1500         364       7        5            6           6
# top      CUST_2423  2025-11-23     usa  Finance         1-10  Mid-Market
# freq             2          11     184      272          285         285

# %% [markdown]
# ## Quality Check

# %%
customers.columns
# Out:
# Index(['customer_id', 'signup_date', 'country', 'industry', 'company_size',
#        'segment'],
#       dtype='object')

# %%
customers.isnull().sum()
# Out:
# customer_id       0
# signup_date       0
# country         348
# industry        245
# company_size      0
# segment           0
# dtype: int64

# %%
customers.duplicated().sum()
# Out:
# np.int64(50)

# %%
customers['customer_id'].duplicated().sum()
# Out:
# np.int64(50)

# %%
customers.nunique()
# Out:
# customer_id     1500
# signup_date      364
# country            7
# industry           5
# company_size       6
# segment            6
# dtype: int64

# %%
customers[customers.duplicated(subset="customer_id", keep=False)]
# Out:
#       customer_id signup_date         country    industry company_size  \
# 51      CUST_2051  2025-03-17              UK     Finance         1-10
# 70      CUST_2070  2025-07-08             usa        SaaS      201-500
# 76      CUST_2076  2025-11-08              UK  Healthcare        11-50
# 220     CUST_2220  2025-06-13              US         NaN       51-200
# 259     CUST_2259  2025-06-12   United States     Finance         1-10
# 309     CUST_2309  2025-09-06              UK         NaN       51-200
# 339     CUST_2339  2025-11-23  united kingdom         NaN         1-10
# 354     CUST_2354  2025-05-13   United States  E-commerce        11-50
# 365     CUST_2365  2025-08-05             NaN         NaN         1-10
# 413     CUST_2413  2025-07-01              CA         NaN      unknown
# 422     CUST_2422  2025-10-01             NaN        SaaS       51-200
# 423     CUST_2423  2025-09-14              CA  E-commerce         1-10
# ...

# %%
customers["customer_id"].value_counts()[customers["customer_id"].value_counts() > 1]
# Out:
# customer_id
# CUST_2423      2
# CUST_2259      2
# CUST_2070      2
# CUST_2736      2
# CUST_2712      2
# CUST_3491      2
# CUST_2413      2
# CUST_3470      2
# CUST_2610      2
# CUST_2741      2
# CUST_2076      2
# CUST_2428      2
# CUST_2451      2
# CUST_2365      2
# CUST_2439      2
# CUST_2607      2
# CUST_2432      2
# CUST_2354      2
# CUST_2339      2
#  CUST_2433     2
# CUST_2422      2
# CUST_2220      2
# CUST_2309      2
# CUST_2861      2
# CUST_2864      2
#  CUST_2888     2
# CUST_2998      2
# CUST_3041      2
# CUST_3063      2
# CUST_3080      2
# CUST_3085      2
# CUST_3105      2
# CUST_3116      2
# CUST_3128      2
# CUST_3190      2
# CUST_3199      2
# CUST_3234      2
# CUST_3249      2
# CUST_3268      2
# CUST_3272      2
# CUST_3281      2
# CUST_3284      2
# CUST_3336      2
# CUST_3368      2
# CUST_3382      2
# CUST_3391      2
# CUST_3419      2
# CUST_3432      2
# CUST_2051      2
# CUST_3452      2
# Name: count, dtype: int64

# %%
customers.dtypes
# Out:
# customer_id     object
# signup_date     object
# country         object
# industry        object
# company_size    object
# segment         object
# dtype: object

# %%
customers.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1550 entries, 0 to 1549
# Data columns (total 6 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   customer_id   1550 non-null   object
#  1   signup_date   1550 non-null   object
#  2   country       1202 non-null   object
#  3   industry      1305 non-null   object
#  4   company_size  1550 non-null   object
#  5   segment       1550 non-null   object
# dtypes: object(6)
# memory usage: 72.8+ KB

# %%
customers['country'].unique()
# Out:
# array([nan, 'usa', 'Canada', 'united kingdom', 'CA', 'United States',
#        'US', 'UK'], dtype=object)

# %%
customers['country'].value_counts(dropna=False)
# Out:
# country
# NaN               348
# usa               184
# Canada            182
# US                182
# United States     174
# CA                170
# united kingdom    155
# UK                155
# Name: count, dtype: int64

# %%
customers['industry'].unique()
# Out:
# array(['Logistics', 'E-commerce', 'Finance', nan, 'SaaS', 'Healthcare'],
#       dtype=object)

# %%
customers['industry'].value_counts(dropna=False)
# Out:
# industry
# SaaS          272
# Finance       272
# E-commerce    270
# Healthcare    263
# NaN           245
# Logistics     228
# Name: count, dtype: int64

# %%
customers['segment'].unique()
# Out:
# array(['SMB', 'Enterprise', 'small business', 'ENT', 'Mid-Market', 'mid'],
#       dtype=object)

# %%
customers['segment'].value_counts(dropna=False)
# Out:
# segment
# Mid-Market        285
# small business    265
# mid               265
# SMB               260
# ENT               244
# Enterprise        231
# Name: count, dtype: int64

# %%
customers['signup_date'].min()
# Out:
# '2025-01-01'

# %%
customers['signup_date'].max()
# Out:
# '2025-12-31'

# %% [markdown]
# ## Data Cleaning

# %%
customers.drop_duplicates(subset='customer_id',inplace=True)

# %%
customers.duplicated().sum()
# Out:
# np.int64(0)

# %%
customers.head(2)
# Out:
#   customer_id signup_date country    industry company_size     segment
# 0   CUST_2000  2025-09-15     NaN   Logistics      unknown         SMB
# 1   CUST_2001  2025-10-10     NaN  E-commerce         500+  Enterprise

# %%
customers['country'].isnull().sum()
# Out:
# np.int64(337)

# %%
customers['country']=customers['country'].fillna("Unknown")

# %%
customers['country'].isnull().sum()
# Out:
# np.int64(0)

# %%
customers["industry"].isnull().sum()
# Out:
# np.int64(231)

# %%
customers['industry']=customers['industry'].fillna("Unknown")

# %%
customers["industry"].isnull().sum()
# Out:
# np.int64(0)

# %%
customers.isnull().sum()
# Out:
# customer_id     0
# signup_date     0
# country         0
# industry        0
# company_size    0
# segment         0
# dtype: int64

# %%
customers['country']=customers['country'].replace(["usa","United States","US"],"USA")
customers['country']=customers['country'].replace("CA","Canada")
customers['country']=customers['country'].replace("united kingdom","UK")

# %%
customers['country'].value_counts()
# Out:
# country
# USA        523
# Canada     340
# Unknown    337
# UK         300
# Name: count, dtype: int64

# %%
customers['industry'].value_counts()
# Out:
# industry
# SaaS          269
# Finance       263
# E-commerce    260
# Healthcare    254
# Unknown       231
# Logistics     223
# Name: count, dtype: int64

# %%
customers['segment'].unique()
# Out:
# array(['SMB', 'Enterprise', 'small business', 'ENT', 'Mid-Market', 'mid'],
#       dtype=object)

# %%
customers['segment']=customers['segment'].replace({"small business":"SMB","Enterprise":"ENT","Mid-Market":"MID","mid":"MID"})

# %%
customers['segment'].value_counts()
# Out:
# segment
# MID    529
# SMB    510
# ENT    461
# Name: count, dtype: int64

# %%
customers.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1500 entries, 0 to 1499
# Data columns (total 6 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   customer_id   1500 non-null   object
#  1   signup_date   1500 non-null   object
#  2   country       1500 non-null   object
#  3   industry      1500 non-null   object
#  4   company_size  1500 non-null   object
#  5   segment       1500 non-null   object
# dtypes: object(6)
# memory usage: 82.0+ KB

# %%
customers['signup_date']=pd.to_datetime(customers['signup_date'],errors='coerce')

# %%
customers.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1500 entries, 0 to 1499
# Data columns (total 6 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   customer_id   1500 non-null   object
#  1   signup_date   1500 non-null   datetime64[ns]
#  2   country       1500 non-null   object
#  3   industry      1500 non-null   object
#  4   company_size  1500 non-null   object
#  5   segment       1500 non-null   object
# dtypes: datetime64[ns](1), object(5)
# memory usage: 82.0+ KB

# %%
customers["company_size"].value_counts(dropna=False)
# Out:
# company_size
# 1-10       274
# 11-50      262
# 51-200     256
# 201-500    247
# unknown    236
# 500+       225
# Name: count, dtype: int64

# %%
customers.columns=customers.columns.str.title()

# %%
customers_clean=customers.copy()

# %%
customers_clean.to_csv("customers_clean.csv",index=False)

# %%
customers_clean
# Out:
#       Customer_Id Signup_Date  Country    Industry Company_Size Segment
# 0       CUST_2000  2025-09-15  Unknown   Logistics      unknown     SMB
# 1       CUST_2001  2025-10-10  Unknown  E-commerce         500+     ENT
# 2       CUST_2002  2025-03-19  Unknown   Logistics      201-500     SMB
# 3      CUST_2003   2025-11-30      USA     Finance       51-200     SMB
# 4       CUST_2004  2025-01-30  Unknown     Unknown       51-200     SMB
# ...           ...         ...      ...         ...          ...     ...
# 1495    CUST_3495  2025-09-30      USA        SaaS         500+     MID
# 1496    CUST_3496  2025-07-19      USA  Healthcare        11-50     ENT
# 1497    CUST_3497  2025-03-25   Canada        SaaS        11-50     SMB
# 1498   CUST_3498   2025-01-13       UK     Unknown       51-200     ENT
# 1499    CUST_3499  2025-02-09  Unknown  E-commerce         1-10     SMB
#
# [1500 rows x 6 columns]

# %% [markdown]
# # 2. Plans Dataset

# %% [markdown]
# ## Data Inspection

# %%
plans
# Out:
#    plan_id   plan_name  monthly_price billing_cycle
# 0  p_basic       Basic           29.0       Monthly
# 1    p_pro         Pro           79.0       Monthly
# 2    p_ent  Enterprise          499.0        Annual

# %%
plans.shape
# Out:
# (3, 4)

# %%
plans.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 4 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   plan_id        3 non-null      object
#  1   plan_name      3 non-null      object
#  2   monthly_price  3 non-null      float64
#  3   billing_cycle  3 non-null      object
# dtypes: float64(1), object(3)
# memory usage: 228.0+ bytes

# %%
plans.describe()
# Out:
#        monthly_price
# count       3.000000
# mean      202.333333
# std       258.134332
# min        29.000000
# 25%        54.000000
# 50%        79.000000
# 75%       289.000000
# max       499.000000

# %% [markdown]
# ## Data Qualitycheck

# %%
plans.columns
# Out:
# Index(['plan_id', 'plan_name', 'monthly_price', 'billing_cycle'], dtype='object')

# %%
plans.isnull().sum()
# Out:
# plan_id          0
# plan_name        0
# monthly_price    0
# billing_cycle    0
# dtype: int64

# %%
plans.duplicated().sum()
# Out:
# np.int64(0)

# %%
plans.columns=plans.columns.str.title()

# %%
plans
# Out:
#    Plan_Id   Plan_Name  Monthly_Price Billing_Cycle
# 0  p_basic       Basic           29.0       Monthly
# 1    p_pro         Pro           79.0       Monthly
# 2    p_ent  Enterprise          499.0        Annual

# %%
plans_clean=plans.copy()

# %%
plans_clean.to_csv('plans_clean.csv',index=False)

# %%
plans_clean
# Out:
#    Plan_Id   Plan_Name  Monthly_Price Billing_Cycle
# 0  p_basic       Basic           29.0       Monthly
# 1    p_pro         Pro           79.0       Monthly
# 2    p_ent  Enterprise          499.0        Annual

# %% [markdown]
# # 3. Subscriptions Dataset

# %% [markdown]
# ## Data Inspection

# %%
subscriptions
# Out:
#      subscription_id customer_id  plan_id  start_date    end_date       status
# 0          SUB_30000   CUST_2000    p_ent  2025-09-16         NaN          ACT
# 1          SUB_30001   CUST_2001   P_PRO   2025-10-10         NaN          ACT
# 2          SUB_30002   CUST_2002    p_ent  2025-03-21         NaN       active
# 3          SUB_30003   CUST_2003    p_ent  2025-12-02  2026-07-01     canceled
# 4          SUB_30004   CUST_2004    p_ent  2025-01-30         NaN       active
# ...              ...         ...      ...         ...         ...          ...
# 1495       SUB_31495   CUST_3495   P_PRO   2025-09-30         NaN          ACT
# 1496       SUB_31496   CUST_3496    p_ent  2025-07-20         NaN          ACT
# 1497       SUB_31497   CUST_3497  p_basic  2025-03-26  2025-11-11    cancelled
# 1498       SUB_31498   CUST_3498    p_pro  2025-01-15         NaN  active_plan
# 1499       SUB_31499   CUST_3499    p_ent  2025-02-09         NaN       active
#
# [1500 rows x 6 columns]

# %%
subscriptions.shape
# Out:
# (1500, 6)

# %%
subscriptions.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1500 entries, 0 to 1499
# Data columns (total 6 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   subscription_id  1500 non-null   object
#  1   customer_id      1500 non-null   object
#  2   plan_id          1500 non-null   object
#  3   start_date       1500 non-null   object
#  4   end_date         457 non-null    object
#  5   status           1500 non-null   object
# dtypes: object(6)
# memory usage: 70.4+ KB

# %%
subscriptions.describe(include='all')
# Out:
#        subscription_id customer_id plan_id  start_date    end_date  \
# count             1500        1500    1500        1500         457
# unique            1500        1500       4         358         282
# top          SUB_31499   CUST_3499   p_ent  2025-11-23  2025-10-21
# freq                 1           1     394          12           7
#
#              status
# count          1500
# unique            6
# top     active_plan
# freq            378

# %%
subscriptions.head()
# Out:
#   subscription_id customer_id plan_id  start_date    end_date    status
# 0       SUB_30000   CUST_2000   p_ent  2025-09-16         NaN       ACT
# 1       SUB_30001   CUST_2001  P_PRO   2025-10-10         NaN       ACT
# 2       SUB_30002   CUST_2002   p_ent  2025-03-21         NaN    active
# 3       SUB_30003   CUST_2003   p_ent  2025-12-02  2026-07-01  canceled
# 4       SUB_30004   CUST_2004   p_ent  2025-01-30         NaN    active

# %%
subscriptions.tail()
# Out:
#      subscription_id customer_id  plan_id  start_date    end_date       status
# 1495       SUB_31495   CUST_3495   P_PRO   2025-09-30         NaN          ACT
# 1496       SUB_31496   CUST_3496    p_ent  2025-07-20         NaN          ACT
# 1497       SUB_31497   CUST_3497  p_basic  2025-03-26  2025-11-11    cancelled
# 1498       SUB_31498   CUST_3498    p_pro  2025-01-15         NaN  active_plan
# 1499       SUB_31499   CUST_3499    p_ent  2025-02-09         NaN       active

# %%
subscriptions.sample(10)
# Out:
#      subscription_id customer_id  plan_id  start_date    end_date       status
# 1468       SUB_31468   CUST_3468    p_ent  2025-10-19  2025-12-30      churned
# 762        SUB_30762   CUST_2762    p_pro  2025-04-15  2025-09-16    cancelled
# 300        SUB_30300   CUST_2300   P_PRO   2025-04-05         NaN  active_plan
# 164        SUB_30164   CUST_2164    p_ent  2025-03-14  2025-07-23    cancelled
# 246        SUB_30246   CUST_2246  p_basic  2025-02-17         NaN          ACT
# 647        SUB_30647   CUST_2647  p_basic  2025-09-23         NaN       active
# 1031       SUB_31031   CUST_3031    p_ent  2025-04-22         NaN       active
# 649        SUB_30649   CUST_2649   P_PRO   2025-10-08  2026-05-03     canceled
# 642        SUB_30642   CUST_2642   P_PRO   2025-06-20         NaN       active
# 1148       SUB_31148   CUST_3148    p_pro  2025-07-13         NaN       active

# %%
subscriptions.dtypes
# Out:
# subscription_id    object
# customer_id        object
# plan_id            object
# start_date         object
# end_date           object
# status             object
# dtype: object

# %%
subscriptions.columns
# Out:
# Index(['subscription_id', 'customer_id', 'plan_id', 'start_date', 'end_date',
#        'status'],
#       dtype='object')

# %% [markdown]
# ## Data Qualitycheck

# %%
subscriptions.isnull().sum()
# Out:
# subscription_id       0
# customer_id           0
# plan_id               0
# start_date            0
# end_date           1043
# status                0
# dtype: int64

# %%
subscriptions.duplicated().sum()
# Out:
# np.int64(0)

# %%
subscriptions['subscription_id'].duplicated().sum()
# Out:
# np.int64(0)

# %%
customers.columns
# Out:
# Index(['Customer_Id', 'Signup_Date', 'Country', 'Industry', 'Company_Size',
#        'Segment'],
#       dtype='object')

# %%
subscriptions[~subscriptions['customer_id'].isin(customers['Customer_Id'])]
# Out:
#      subscription_id customer_id  plan_id  start_date    end_date       status
# 3          SUB_30003   CUST_2003    p_ent  2025-12-02  2026-07-01     canceled
# 28         SUB_30028   CUST_2028    p_pro  2025-12-19  2026-03-22     canceled
# 36         SUB_30036   CUST_2036    p_pro  2025-06-03  2025-07-03    cancelled
# 43         SUB_30043   CUST_2043    p_pro  2025-09-19         NaN       active
# 63         SUB_30063   CUST_2063  p_basic  2025-03-08         NaN  active_plan
# ...              ...         ...      ...         ...         ...          ...
# 1457       SUB_31457   CUST_3457    p_ent  2025-05-07  2025-11-17      churned
# 1467       SUB_31467   CUST_3467    p_ent  2025-02-22  2025-07-29    cancelled
# 1486       SUB_31486   CUST_3486    p_ent  2025-08-09         NaN  active_plan
# 1493       SUB_31493   CUST_3493   P_PRO   2025-05-04         NaN          ACT
# 1498       SUB_31498   CUST_3498    p_pro  2025-01-15         NaN  active_plan
#
# [121 rows x 6 columns]

# %%
len(subscriptions[~subscriptions['customer_id'].isin(customers['Customer_Id'])])
# Out:
# 121

# %%
subscriptions['plan_id'].value_counts(dropna=False)
# Out:
# plan_id
# p_ent      394
# p_pro      390
# P_PRO      359
# p_basic    357
# Name: count, dtype: int64

# %%
subscriptions['plan_id'].unique()
# Out:
# array(['p_ent', 'P_PRO ', 'p_pro', 'p_basic'], dtype=object)

# %%
subscriptions['status'].value_counts(dropna=False)
# Out:
# status
# active_plan    378
# ACT            333
# active         332
# canceled       166
# churned        151
# cancelled      140
# Name: count, dtype: int64

# %%
subscriptions['status'].unique()
# Out:
# array(['ACT', 'active', 'canceled', 'active_plan', 'cancelled', 'churned'],
#       dtype=object)

# %%
subscriptions.sample(20)
# Out:
#      subscription_id customer_id  plan_id  start_date    end_date       status
# 25         SUB_30025   CUST_2025    p_pro  2025-02-17  2025-08-07     canceled
# 1148       SUB_31148   CUST_3148    p_pro  2025-07-13         NaN       active
# 857        SUB_30857   CUST_2857  p_basic  2025-08-30         NaN  active_plan
# 1346       SUB_31346   CUST_3346   P_PRO   2025-04-07  2025-09-13     canceled
# 652        SUB_30652   CUST_2652    p_pro  2025-08-21         NaN  active_plan
# 214        SUB_30214   CUST_2214    p_ent  2025-03-22         NaN       active
# 140        SUB_30140   CUST_2140  p_basic  2025-04-28         NaN       active
# 1351       SUB_31351   CUST_3351  p_basic  2025-04-16  2025-04-07    cancelled
# 618        SUB_30618   CUST_2618    p_ent  2025-08-19         NaN          ACT
# 97         SUB_30097   CUST_2097   P_PRO   2025-04-05         NaN  active_plan
# 261        SUB_30261   CUST_2261  p_basic  2025-09-07         NaN       active
# ...

# %% [markdown]
# ## Data Cleanin

# %%
subscriptions=subscriptions[subscriptions['customer_id'].isin(customers['Customer_Id'])].copy()

# %%
subscriptions[~subscriptions['customer_id'].isin(customers['Customer_Id'])]
# Out:
# Empty DataFrame
# Columns: [subscription_id, customer_id, plan_id, start_date, end_date, status]
# Index: []

# %%
subscriptions[~subscriptions['customer_id'].isin(customers['Customer_Id'])]
# Out:
# Empty DataFrame
# Columns: [subscription_id, customer_id, plan_id, start_date, end_date, status]
# Index: []

# %%
subscriptions['plan_id']=subscriptions['plan_id'].str.strip()
subscriptions['plan_id']=subscriptions['plan_id'].str.lower()

# %%
subscriptions['plan_id'].sample(5)
# Out:
# 956     p_basic
# 450       p_pro
# 691     p_basic
# 1476      p_ent
# 462       p_ent
# Name: plan_id, dtype: object

# %%
subscriptions['status']=subscriptions['status'].replace(['ACT', 'active','active_plan'],"Active")

# %%
subscriptions['status']=subscriptions['status'].replace(['canceled','cancelled'],"cancelled")

# %%
subscriptions['status'].value_counts()
# Out:
# status
# Active       965
# cancelled    279
# churned      135
# Name: count, dtype: int64

# %%
subscriptions['status']=subscriptions['status'].str.title()

# %%
subscriptions[(subscriptions['status']=='Active') & (subscriptions['end_date'].notna())]
# Out:
# Empty DataFrame
# Columns: [subscription_id, customer_id, plan_id, start_date, end_date, status]
# Index: []

# %%
subscriptions[(subscriptions['status'].isin(['Cancelled','Churned'])) & (subscriptions['end_date'].isna())]
# Out:
# Empty DataFrame
# Columns: [subscription_id, customer_id, plan_id, start_date, end_date, status]
# Index: []

# %%
subscriptions.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1379 entries, 0 to 1499
# Data columns (total 6 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   subscription_id  1379 non-null   object
#  1   customer_id      1379 non-null   object
#  2   plan_id          1379 non-null   object
#  3   start_date       1379 non-null   object
#  4   end_date         414 non-null    object
#  5   status           1379 non-null   object
# dtypes: object(6)
# memory usage: 75.4+ KB

# %%
subscriptions['start_date']=pd.to_datetime(subscriptions['start_date'],errors='coerce')

# %%
subscriptions['end_date']=pd.to_datetime(subscriptions['end_date'],errors='coerce')

# %%
subscriptions.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1379 entries, 0 to 1499
# Data columns (total 6 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   subscription_id  1379 non-null   object
#  1   customer_id      1379 non-null   object
#  2   plan_id          1379 non-null   object
#  3   start_date       1379 non-null   datetime64[ns]
#  4   end_date         414 non-null    datetime64[ns]
#  5   status           1379 non-null   object
# dtypes: datetime64[ns](2), object(4)
# memory usage: 75.4+ KB

# %%
subscriptions['subscription_days']=(subscriptions['end_date']-subscriptions['start_date']).dt.days

# %%
subscriptions[subscriptions['subscription_days']<0]
# Out:
#      subscription_id customer_id  plan_id start_date   end_date     status  \
# 307        SUB_30307   CUST_2307  p_basic 2025-12-15 2025-12-01  Cancelled
# 352        SUB_30352   CUST_2352  p_basic 2025-08-28 2025-08-09    Churned
# 424        SUB_30424   CUST_2424    p_pro 2025-12-13 2025-12-03  Cancelled
# 586        SUB_30586   CUST_2586  p_basic 2025-08-11 2025-07-28  Cancelled
# 613        SUB_30613   CUST_2613    p_ent 2025-11-21 2025-11-05  Cancelled
# 678        SUB_30678   CUST_2678    p_ent 2025-03-10 2025-02-25  Cancelled
# 778        SUB_30778   CUST_2778    p_pro 2025-01-03 2024-12-16  Cancelled
# 858        SUB_30858   CUST_2858  p_basic 2025-05-24 2025-05-15  Cancelled
# 969        SUB_30969   CUST_2969    p_ent 2025-09-17 2025-09-07  Cancelled
# 988        SUB_30988   CUST_2988    p_ent 2025-09-26 2025-09-14  Cancelled
# 1114       SUB_31114   CUST_3114    p_pro 2025-02-17 2025-02-09  Cancelled
# ...

# %%
(subscriptions['subscription_days']<0).sum()
# Out:
# np.int64(21)

# %%
subscriptions=subscriptions[(subscriptions['subscription_days']>=0) | (subscriptions['subscription_days'].isna())]

# %%
(subscriptions['subscription_days']<0).sum()
# Out:
# np.int64(0)

# %%
subscriptions
# Out:
#      subscription_id customer_id  plan_id start_date   end_date     status  \
# 0          SUB_30000   CUST_2000    p_ent 2025-09-16        NaT     Active
# 1          SUB_30001   CUST_2001    p_pro 2025-10-10        NaT     Active
# 2          SUB_30002   CUST_2002    p_ent 2025-03-21        NaT     Active
# 4          SUB_30004   CUST_2004    p_ent 2025-01-30        NaT     Active
# 5          SUB_30005   CUST_2005    p_pro 2025-04-28        NaT     Active
# ...              ...         ...      ...        ...        ...        ...
# 1494       SUB_31494   CUST_3494    p_pro 2025-01-25 2025-07-05    Churned
# 1495       SUB_31495   CUST_3495    p_pro 2025-09-30        NaT     Active
# 1496       SUB_31496   CUST_3496    p_ent 2025-07-20        NaT     Active
# 1497       SUB_31497   CUST_3497  p_basic 2025-03-26 2025-11-11  Cancelled
# 1499       SUB_31499   CUST_3499    p_ent 2025-02-09        NaT     Active
#
#       subscription_days
# 0                   NaN
# ...

# %%
subscriptions["subscription_days"] = subscriptions["subscription_days"].fillna(0)

# %%
subscriptions["subscription_days"] = subscriptions["subscription_days"].astype(int)

# %%
subscriptions.columns=subscriptions.columns.str.title()

# %%
subscriptions
# Out:
#      Subscription_Id Customer_Id  Plan_Id Start_Date   End_Date     Status  \
# 0          SUB_30000   CUST_2000    p_ent 2025-09-16        NaT     Active
# 1          SUB_30001   CUST_2001    p_pro 2025-10-10        NaT     Active
# 2          SUB_30002   CUST_2002    p_ent 2025-03-21        NaT     Active
# 4          SUB_30004   CUST_2004    p_ent 2025-01-30        NaT     Active
# 5          SUB_30005   CUST_2005    p_pro 2025-04-28        NaT     Active
# ...              ...         ...      ...        ...        ...        ...
# 1494       SUB_31494   CUST_3494    p_pro 2025-01-25 2025-07-05    Churned
# 1495       SUB_31495   CUST_3495    p_pro 2025-09-30        NaT     Active
# 1496       SUB_31496   CUST_3496    p_ent 2025-07-20        NaT     Active
# 1497       SUB_31497   CUST_3497  p_basic 2025-03-26 2025-11-11  Cancelled
# 1499       SUB_31499   CUST_3499    p_ent 2025-02-09        NaT     Active
#
#       Subscription_Days
# 0                     0
# ...

# %%
subscriptions_clean=subscriptions.copy()

# %%
subscriptions_clean
# Out:
#      Subscription_Id Customer_Id  Plan_Id Start_Date   End_Date     Status  \
# 0          SUB_30000   CUST_2000    p_ent 2025-09-16        NaT     Active
# 1          SUB_30001   CUST_2001    p_pro 2025-10-10        NaT     Active
# 2          SUB_30002   CUST_2002    p_ent 2025-03-21        NaT     Active
# 4          SUB_30004   CUST_2004    p_ent 2025-01-30        NaT     Active
# 5          SUB_30005   CUST_2005    p_pro 2025-04-28        NaT     Active
# ...              ...         ...      ...        ...        ...        ...
# 1494       SUB_31494   CUST_3494    p_pro 2025-01-25 2025-07-05    Churned
# 1495       SUB_31495   CUST_3495    p_pro 2025-09-30        NaT     Active
# 1496       SUB_31496   CUST_3496    p_ent 2025-07-20        NaT     Active
# 1497       SUB_31497   CUST_3497  p_basic 2025-03-26 2025-11-11  Cancelled
# 1499       SUB_31499   CUST_3499    p_ent 2025-02-09        NaT     Active
#
#       Subscription_Days
# 0                     0
# ...

# %%
subscriptions_clean.to_csv('subscriptions_clean.csv',index=False,na_rep="")

# %% [markdown]
# # 4. Payments Dataset

# %% [markdown]
# ## Data Inspection

# %%
payments
# Out:
#       payment_id subscription_id payment_date  amount payment_status  \
# 0     PAY_500001       SUB_30000   2025-09-16   499.0       refunded
# 1     PAY_500002       SUB_30001   2025-10-13    79.0           paid
# 2     PAY_500003       SUB_30002   2025-03-24   499.0         failed
# 3     PAY_500004       SUB_30002   2025-04-23   499.0         failed
# 4     PAY_500005       SUB_30002   2025-05-21   499.0         failed
# ...          ...             ...          ...     ...            ...
# 3058  PAY_503059       SUB_31496   2025-08-22   499.0         failed
# 3059  PAY_503060       SUB_31496   2025-09-18   499.0           PAID
# 3060  PAY_503061       SUB_31497   2025-03-27    29.0       refunded
# 3061  PAY_503062       SUB_31498   2025-01-16    79.0         failed
# 3062  PAY_503063       SUB_31499   2025-02-11   499.0       refunded
#
#      payment_method
# 0       CREDIT_CARD
# 1            STRIPE
# 2               ACH
# 3            PAYPAL
# 4       CREDIT_CARD
# ...

# %%
payments.shape
# Out:
# (3063, 6)

# %%
payments.columns
# Out:
# Index(['payment_id', 'subscription_id', 'payment_date', 'amount',
#        'payment_status', 'payment_method'],
#       dtype='object')

# %%
payments.head()
# Out:
#    payment_id subscription_id payment_date  amount payment_status  \
# 0  PAY_500001       SUB_30000   2025-09-16   499.0       refunded
# 1  PAY_500002       SUB_30001   2025-10-13    79.0           paid
# 2  PAY_500003       SUB_30002   2025-03-24   499.0         failed
# 3  PAY_500004       SUB_30002   2025-04-23   499.0         failed
# 4  PAY_500005       SUB_30002   2025-05-21   499.0         failed
#
#   payment_method
# 0    CREDIT_CARD
# 1         STRIPE
# 2            ACH
# 3         PAYPAL
# 4    CREDIT_CARD

# %%
payments.tail()
# Out:
#       payment_id subscription_id payment_date  amount payment_status  \
# 3058  PAY_503059       SUB_31496   2025-08-22   499.0         failed
# 3059  PAY_503060       SUB_31496   2025-09-18   499.0           PAID
# 3060  PAY_503061       SUB_31497   2025-03-27    29.0       refunded
# 3061  PAY_503062       SUB_31498   2025-01-16    79.0         failed
# 3062  PAY_503063       SUB_31499   2025-02-11   499.0       refunded
#
#      payment_method
# 3058    CREDIT_CARD
# 3059    CREDIT_CARD
# 3060         STRIPE
# 3061         STRIPE
# 3062            ACH

# %%
payments.sample(5)
# Out:
#       payment_id subscription_id payment_date  amount payment_status  \
# 1758  PAY_501759       SUB_30883   2025-04-27    29.0           PAID
# 1441  PAY_501442       SUB_30725   2025-01-20   499.0           PAID
# 1651  PAY_501652       SUB_30829   2026-01-12   499.0         failed
# 3040  PAY_503041       SUB_31488   2025-05-12   499.0       refunded
# 2870  PAY_502871       SUB_31397   2025-10-12    79.0           paid
#
#      payment_method
# 1758            ACH
# 1441            ACH
# 1651    CREDIT_CARD
# 3040         PAYPAL
# 2870    CREDIT_CARD

# %%
payments.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3063 entries, 0 to 3062
# Data columns (total 6 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   payment_id       3063 non-null   object
#  1   subscription_id  3063 non-null   object
#  2   payment_date     3063 non-null   object
#  3   amount           3063 non-null   float64
#  4   payment_status   3063 non-null   object
#  5   payment_method   3063 non-null   object
# dtypes: float64(1), object(5)
# memory usage: 143.7+ KB

# %%
payments.describe(include='all')
# Out:
#         payment_id subscription_id payment_date       amount payment_status  \
# count         3063            3063         3063  3063.000000           3063
# unique        3063            1500          442          NaN              4
# top     PAY_503063       SUB_30009   2025-08-13          NaN           paid
# freq             1               4           19          NaN            788
# mean           NaN             NaN          NaN   170.734900            NaN
# std            NaN             NaN          NaN   199.738994            NaN
# min            NaN             NaN          NaN  -499.000000            NaN
# 25%            NaN             NaN          NaN    29.000000            NaN
# 50%            NaN             NaN          NaN    79.000000            NaN
# 75%            NaN             NaN          NaN   499.000000            NaN
# max            NaN             NaN          NaN   499.000000            NaN
#
#        payment_method
# count            3063
# ...

# %% [markdown]
# ## Data Qualitycheck

# %%
payments.columns
# Out:
# Index(['payment_id', 'subscription_id', 'payment_date', 'amount',
#        'payment_status', 'payment_method'],
#       dtype='object')

# %%
payments.isnull().sum()
# Out:
# payment_id         0
# subscription_id    0
# payment_date       0
# amount             0
# payment_status     0
# payment_method     0
# dtype: int64

# %%
payments.duplicated().sum()
# Out:
# np.int64(0)

# %%
payments["payment_id"].duplicated().sum()
# Out:
# np.int64(0)

# %%
payments = payments[payments["subscription_id"].isin(subscriptions["Subscription_Id"])]

# %%
payments[~payments['subscription_id'].isin(subscriptions['Subscription_Id'])]
# Out:
# Empty DataFrame
# Columns: [payment_id, subscription_id, payment_date, amount, payment_status, payment_method]
# Index: []

# %%
payments.dtypes
# Out:
# payment_id          object
# subscription_id     object
# payment_date        object
# amount             float64
# payment_status      object
# payment_method      object
# dtype: object

# %% [markdown]
# ## Data Cleaning

# %%
payments['payment_status'].value_counts(dropna=False)
# Out:
# payment_status
# paid        716
# failed      706
# PAID        704
# refunded    687
# Name: count, dtype: int64

# %%
payments['payment_status']=payments['payment_status'].replace(["paid","PAID"],"Paid")
payments['payment_status']=payments['payment_status'].str.title()
# Out:
# C:\Users\Suji Prasanth\AppData\Local\Temp\ipykernel_18456\3905524005.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   payments['payment_status']=payments['payment_status'].replace(["paid","PAID"],"Paid")
# C:\Users\Suji Prasanth\AppData\Local\Temp\ipykernel_18456\3905524005.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   payments['payment_status']=payments['payment_status'].str.title()

# %%
payments[payments['amount']<0]
# Out:
#       payment_id subscription_id payment_date  amount payment_status  \
# 115   PAY_500116       SUB_30056   2025-08-14  -499.0           Paid
# 188   PAY_500189       SUB_30089   2025-03-30   -79.0       Refunded
# 406   PAY_500407       SUB_30206   2025-02-07   -79.0         Failed
# 452   PAY_500453       SUB_30225   2025-11-05   -29.0           Paid
# 501   PAY_500502       SUB_30248   2025-03-13   -29.0       Refunded
# 585   PAY_500586       SUB_30290   2025-05-04   -79.0         Failed
# 635   PAY_500636       SUB_30316   2025-11-30  -499.0       Refunded
# 638   PAY_500639       SUB_30318   2025-07-31   -79.0           Paid
# 708   PAY_500709       SUB_30349   2025-12-13   -29.0           Paid
# 791   PAY_500792       SUB_30398   2025-04-29   -29.0           Paid
# 969   PAY_500970       SUB_30485   2025-07-12   -29.0           Paid
# 983   PAY_500984       SUB_30491   2025-04-03  -499.0           Paid
# 989   PAY_500990       SUB_30494   2025-05-16   -79.0           Paid
# ...

# %%
(payments['amount']<0).sum()
# Out:
# np.int64(45)

# %%
payments.groupby("payment_status")["amount"].apply(lambda x: (x < 0).sum())
# Out:
# payment_status
# Failed      10
# Paid        23
# Refunded    12
# Name: amount, dtype: int64

# %%
payments['amount'].value_counts()
# Out:
# amount
#  79.0     1365
#  499.0     724
#  29.0      679
# -79.0       18
# -499.0      15
# -29.0       12
# Name: count, dtype: int64

# %%
mask=((payments['amount'])<0 &( payments['payment_status'].isin(['Paid','Failed'])))
payments.loc[mask,'amount']=payments.loc[mask,'amount'].abs()

# %%
mask=payments['payment_status']=="Refunded"
payments.loc[mask,'amount']=-payments.loc[mask,'amount'].abs()

# %%
payments.sample(10)
# Out:
#       payment_id subscription_id payment_date  amount payment_status  \
# 1315  PAY_501316       SUB_30659   2025-02-11   499.0         Failed
# 2380  PAY_502381       SUB_31166   2025-04-15    79.0           Paid
# 807   PAY_500808       SUB_30406   2025-01-13   -79.0       Refunded
# 572   PAY_500573       SUB_30283   2025-06-24    29.0           Paid
# 3037  PAY_503038       SUB_31485   2025-01-10    79.0           Paid
# 8     PAY_500009       SUB_30005   2025-05-28    79.0           Paid
# 1790  PAY_501791       SUB_30897   2026-03-04    29.0           Paid
# 2336  PAY_502337       SUB_31148   2025-07-13    79.0           Paid
# 2304  PAY_502305       SUB_31132   2025-06-17    79.0           Paid
# 286   PAY_500287       SUB_30140   2025-05-28    29.0         Failed
#
#      payment_method
# 1315    CREDIT_CARD
# 2380         PAYPAL
# 807          STRIPE
# 572          STRIPE
# 3037    CREDIT_CARD
# 8            PAYPAL
# 1790            ACH
# 2336         PAYPAL
# ...

# %%
payments[payments['amount']<0]
# Out:
#       payment_id subscription_id payment_date  amount payment_status  \
# 0     PAY_500001       SUB_30000   2025-09-16  -499.0       Refunded
# 16    PAY_500017       SUB_30008   2025-07-28  -499.0       Refunded
# 30    PAY_500031       SUB_30014   2025-04-24   -79.0       Refunded
# 35    PAY_500036       SUB_30015   2026-01-03  -499.0       Refunded
# 42    PAY_500043       SUB_30020   2025-11-15  -499.0       Refunded
# ...          ...             ...          ...     ...            ...
# 3049  PAY_503050       SUB_31491   2025-06-06   -79.0       Refunded
# 3052  PAY_503053       SUB_31492   2025-07-27   -29.0       Refunded
# 3053  PAY_503054       SUB_31492   2025-08-27   -29.0       Refunded
# 3060  PAY_503061       SUB_31497   2025-03-27   -29.0       Refunded
# 3062  PAY_503063       SUB_31499   2025-02-11  -499.0       Refunded
#
#      payment_method
# 0       CREDIT_CARD
# 16              ACH
# 30           STRIPE
# 35           STRIPE
# 42              ACH
# ...

# %%
(payments['amount']<0).sum()
# Out:
# np.int64(687)

# %%
payments.isnull().sum()
# Out:
# payment_id         0
# subscription_id    0
# payment_date       0
# amount             0
# payment_status     0
# payment_method     0
# dtype: int64

# %%
payments.duplicated().sum()
# Out:
# np.int64(0)

# %%
payments['payment_id'].isnull().sum()
# Out:
# np.int64(0)

# %%
payments['payment_id'].duplicated().sum()
# Out:
# np.int64(0)

# %%
payments['payment_date']=pd.to_datetime(payments['payment_date'])
# Out:
# C:\Users\Suji Prasanth\AppData\Local\Temp\ipykernel_18456\3871555744.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   payments['payment_date']=pd.to_datetime(payments['payment_date'])

# %%
payments.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2813 entries, 0 to 3062
# Data columns (total 6 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   payment_id       2813 non-null   object
#  1   subscription_id  2813 non-null   object
#  2   payment_date     2813 non-null   datetime64[ns]
#  3   amount           2813 non-null   float64
#  4   payment_status   2813 non-null   object
#  5   payment_method   2813 non-null   object
# dtypes: datetime64[ns](1), float64(1), object(4)
# memory usage: 153.8+ KB

# %%
payments.dtypes
# Out:
# payment_id                 object
# subscription_id            object
# payment_date       datetime64[ns]
# amount                    float64
# payment_status             object
# payment_method             object
# dtype: object

# %%
payments.columns=payments.columns.str.title()

# %%
payments
# Out:
#       Payment_Id Subscription_Id Payment_Date  Amount Payment_Status  \
# 0     PAY_500001       SUB_30000   2025-09-16  -499.0       Refunded
# 1     PAY_500002       SUB_30001   2025-10-13    79.0           Paid
# 2     PAY_500003       SUB_30002   2025-03-24   499.0         Failed
# 3     PAY_500004       SUB_30002   2025-04-23   499.0         Failed
# 4     PAY_500005       SUB_30002   2025-05-21   499.0         Failed
# ...          ...             ...          ...     ...            ...
# 3057  PAY_503058       SUB_31496   2025-07-21   499.0           Paid
# 3058  PAY_503059       SUB_31496   2025-08-22   499.0         Failed
# 3059  PAY_503060       SUB_31496   2025-09-18   499.0           Paid
# 3060  PAY_503061       SUB_31497   2025-03-27   -29.0       Refunded
# 3062  PAY_503063       SUB_31499   2025-02-11  -499.0       Refunded
#
#      Payment_Method
# 0       CREDIT_CARD
# 1            STRIPE
# 2               ACH
# 3            PAYPAL
# 4       CREDIT_CARD
# ...

# %%
payments_clean=payments.copy()

# %%
payments_clean.to_csv('payments_clean.csv',index=False)

# %%
payments_clean
# Out:
#       Payment_Id Subscription_Id Payment_Date  Amount Payment_Status  \
# 0     PAY_500001       SUB_30000   2025-09-16  -499.0       Refunded
# 1     PAY_500002       SUB_30001   2025-10-13    79.0           Paid
# 2     PAY_500003       SUB_30002   2025-03-24   499.0         Failed
# 3     PAY_500004       SUB_30002   2025-04-23   499.0         Failed
# 4     PAY_500005       SUB_30002   2025-05-21   499.0         Failed
# ...          ...             ...          ...     ...            ...
# 3057  PAY_503058       SUB_31496   2025-07-21   499.0           Paid
# 3058  PAY_503059       SUB_31496   2025-08-22   499.0         Failed
# 3059  PAY_503060       SUB_31496   2025-09-18   499.0           Paid
# 3060  PAY_503061       SUB_31497   2025-03-27   -29.0       Refunded
# 3062  PAY_503063       SUB_31499   2025-02-11  -499.0       Refunded
#
#      Payment_Method
# 0       CREDIT_CARD
# 1            STRIPE
# 2               ACH
# 3            PAYPAL
# 4       CREDIT_CARD
# ...

# %% [markdown]
# # 5. Usage Dataset

# %% [markdown]
# ## Date Inspection

# %%
usage
# Out:
#          usage_id customer_id  event_date    feature_name  login_count  \
# 0      USG_700001   CUST_2000  2025-09-08  dashboard_view            8
# 1      USG_700002   CUST_2000  2025-05-11      export_csv            3
# 2      USG_700003   CUST_2000  2025-01-17      export_csv            3
# 3      USG_700004   CUST_2000  2025-03-10      export_csv            8
# 4      USG_700005   CUST_2000  2025-05-25      export_csv            3
# ...           ...         ...         ...             ...          ...
# 24751  USG_724752   CUST_2999  2025-01-20     team_invite            1
# 24752  USG_724753   CUST_2999  2025-01-14      export_csv            5
# 24753  USG_724754   CUST_2999  2025-05-20     team_invite            5
# 24754  USG_724755   CUST_2999  2025-10-25      export_csv           -8
# 24755  USG_724756   CUST_2999  2025-01-10    billing_edit            3
#
#        session_minutes
# 0               114.76
# 1                44.68
# 2                76.59
# ...

# %%
usage.shape
# Out:
# (24756, 6)

# %%
usage.columns
# Out:
# Index(['usage_id', 'customer_id', 'event_date', 'feature_name', 'login_count',
#        'session_minutes'],
#       dtype='object')

# %%
usage.dtypes
# Out:
# usage_id            object
# customer_id         object
# event_date          object
# feature_name        object
# login_count          int64
# session_minutes    float64
# dtype: object

# %%
usage.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 24756 entries, 0 to 24755
# Data columns (total 6 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   usage_id         24756 non-null  object
#  1   customer_id      24756 non-null  object
#  2   event_date       24756 non-null  object
#  3   feature_name     23814 non-null  object
#  4   login_count      24756 non-null  int64
#  5   session_minutes  24756 non-null  float64
# dtypes: float64(1), int64(1), object(4)
# memory usage: 1.1+ MB

# %%
usage.describe(include='all')
# Out:
#           usage_id customer_id  event_date    feature_name   login_count  \
# count        24756       24756       24756           23814  24756.000000
# unique       24756        1000         351               5           NaN
# top     USG_724756   CUST_2327  2025-03-16  dashboard_view           NaN
# freq             1          40          94            4849           NaN
# mean           NaN         NaN         NaN             NaN      4.212514
# std            NaN         NaN         NaN             NaN      2.793990
# min            NaN         NaN         NaN             NaN     -8.000000
# 25%            NaN         NaN         NaN             NaN      2.000000
# 50%            NaN         NaN         NaN             NaN      4.000000
# 75%            NaN         NaN         NaN             NaN      6.000000
# max            NaN         NaN         NaN             NaN      8.000000
#
#         session_minutes
# count      24756.000000
# unique              NaN
# ...

# %%
usage.head()
# Out:
#      usage_id customer_id  event_date    feature_name  login_count  \
# 0  USG_700001   CUST_2000  2025-09-08  dashboard_view            8
# 1  USG_700002   CUST_2000  2025-05-11      export_csv            3
# 2  USG_700003   CUST_2000  2025-01-17      export_csv            3
# 3  USG_700004   CUST_2000  2025-03-10      export_csv            8
# 4  USG_700005   CUST_2000  2025-05-25      export_csv            3
#
#    session_minutes
# 0           114.76
# 1            44.68
# 2            76.59
# 3            58.81
# 4            35.41

# %%
usage.tail()
# Out:
#          usage_id customer_id  event_date  feature_name  login_count  \
# 24751  USG_724752   CUST_2999  2025-01-20   team_invite            1
# 24752  USG_724753   CUST_2999  2025-01-14    export_csv            5
# 24753  USG_724754   CUST_2999  2025-05-20   team_invite            5
# 24754  USG_724755   CUST_2999  2025-10-25    export_csv           -8
# 24755  USG_724756   CUST_2999  2025-01-10  billing_edit            3
#
#        session_minutes
# 24751            70.09
# 24752            73.85
# 24753            31.07
# 24754            25.97
# 24755            95.06

# %%
usage.sample(10)
# Out:
#          usage_id customer_id  event_date    feature_name  login_count  \
# 14889  USG_714890   CUST_2598  2025-11-26     team_invite            5
# 9989   USG_709990   CUST_2403  2025-10-24     team_invite            7
# 16749  USG_716750   CUST_2673  2025-04-04  dashboard_view            5
# 2260   USG_702261   CUST_2092  2025-10-24    billing_edit            6
# 12575  USG_712576   CUST_2504  2025-01-07    billing_edit            5
# 5101   USG_705102   CUST_2205  2025-02-12        api_post            4
# 13364  USG_713365   CUST_2536  2025-01-20      export_csv            4
# 4145   USG_704146   CUST_2169  2025-12-02  dashboard_view            1
# 15696  USG_715697   CUST_2629  2025-08-27    billing_edit            1
# 152    USG_700153   CUST_2006  2025-10-09     team_invite            7
#
#        session_minutes
# 14889           104.24
# 9989             69.55
# 16749            58.16
# 2260             49.70
# 12575            88.41
# 5101             66.58
# ...

# %% [markdown]
# ## Data Qualitycheck

# %%
usage.isnull().sum()
# Out:
# usage_id             0
# customer_id          0
# event_date           0
# feature_name       942
# login_count          0
# session_minutes      0
# dtype: int64

# %%
usage.duplicated().sum()
# Out:
# np.int64(0)

# %%
usage['usage_id'].isnull().sum()
# Out:
# np.int64(0)

# %%
usage['customer_id'].isnull().sum()
# Out:
# np.int64(0)

# %%
usage[~usage['customer_id'].isin(customers['Customer_Id'])]
# Out:
#          usage_id customer_id  event_date  feature_name  login_count  \
# 82     USG_700083   CUST_2003  2025-12-13    export_csv            7
# 83     USG_700084   CUST_2003  2025-08-26    export_csv            1
# 84     USG_700085   CUST_2003  2025-06-09    export_csv            2
# 85     USG_700086   CUST_2003  2025-05-02   team_invite            2
# 86     USG_700087   CUST_2003  2025-08-17      api_post            1
# ...           ...         ...         ...           ...          ...
# 24397  USG_724398   CUST_2983  2025-05-23  billing_edit            5
# 24398  USG_724399   CUST_2983  2025-03-18  billing_edit            1
# 24399  USG_724400   CUST_2983  2025-02-13   team_invite            3
# 24400  USG_724401   CUST_2983  2025-11-30   team_invite            7
# 24401  USG_724402   CUST_2983  2025-04-08    export_csv            7
#
#        session_minutes
# 82               98.33
# 83               79.47
# 84               61.47
# 85               99.81
# ...

# %%
usage['feature_name'].value_counts(dropna=False)
# Out:
# feature_name
# dashboard_view    4849
# team_invite       4825
# billing_edit      4724
# export_csv        4717
# api_post          4699
# NaN                942
# Name: count, dtype: int64

# %%
usage['feature_name'].isnull().sum()
# Out:
# np.int64(942)

# %%
usage['feature_name'].value_counts()
# Out:
# feature_name
# dashboard_view    4849
# team_invite       4825
# billing_edit      4724
# export_csv        4717
# api_post          4699
# Name: count, dtype: int64

# %%
usage[usage['login_count']<0]
# Out:
#          usage_id customer_id  event_date    feature_name  login_count  \
# 8      USG_700009   CUST_2000  2025-07-01     team_invite           -2
# 49     USG_700050   CUST_2001  2025-07-21    billing_edit           -7
# 62     USG_700063   CUST_2002  2025-01-25     team_invite           -2
# 69     USG_700070   CUST_2002  2025-04-20    billing_edit           -5
# 81     USG_700082   CUST_2002  2025-09-15      export_csv           -7
# ...           ...         ...         ...             ...          ...
# 24570  USG_724571   CUST_2992  2025-10-04     team_invite           -2
# 24584  USG_724585   CUST_2993  2025-12-05        api_post           -8
# 24652  USG_724653   CUST_2994  2025-10-22  dashboard_view           -3
# 24681  USG_724682   CUST_2997  2025-12-16    billing_edit           -5
# 24754  USG_724755   CUST_2999  2025-10-25      export_csv           -8
#
#        session_minutes
# 8                50.67
# 49               77.09
# 62               86.81
# ...

# %%
(usage['login_count']<0).sum()
# Out:
# np.int64(810)

# %%
usage[usage['session_minutes']<0]
# Out:
# Empty DataFrame
# Columns: [usage_id, customer_id, event_date, feature_name, login_count, session_minutes]
# Index: []

# %%
(usage['session_minutes']<0).sum()
# Out:
# np.int64(0)

# %% [markdown]
# ## Data Cleaning

# %%
usage = usage[usage["customer_id"].isin(customers["Customer_Id"])].copy()

# %%
usage[ ~usage["customer_id"].isin(customers["Customer_Id"])]
# Out:
# Empty DataFrame
# Columns: [usage_id, customer_id, event_date, feature_name, login_count, session_minutes]
# Index: []

# %%
usage['feature_name']=usage['feature_name'].fillna("Unknown")

# %%
usage['feature_name'].value_counts()
# Out:
# feature_name
# team_invite       4419
# dashboard_view    4415
# export_csv        4350
# billing_edit      4343
# api_post          4304
# Unknown            871
# Name: count, dtype: int64

# %%
usage['feature_name']=usage['feature_name'].str.title()

# %%
usage['feature_name'].sample(5)
# Out:
# 8111       Billing_Edit
# 16293    Dashboard_View
# 10803        Export_Csv
# 2646         Export_Csv
# 15757      Billing_Edit
# Name: feature_name, dtype: object

# %%
usage['login_count']=usage['login_count'].abs()

# %%
usage.sample(10)
# Out:
#          usage_id customer_id  event_date  feature_name  login_count  \
# 19126  USG_719127   CUST_2768  2025-04-12   Team_Invite            4
# 13022  USG_713023   CUST_2522  2025-08-08  Billing_Edit            6
# 11480  USG_711481   CUST_2460  2025-02-25    Export_Csv            5
# 16951  USG_716952   CUST_2680  2025-02-16    Export_Csv            2
# 17417  USG_717418   CUST_2700  2025-06-29  Billing_Edit            4
# 4552   USG_704553   CUST_2185  2025-07-21       Unknown            4
# 15025  USG_715026   CUST_2602  2025-10-21    Export_Csv            3
# 6095   USG_706096   CUST_2245  2025-03-14   Team_Invite            4
# 19726  USG_719727   CUST_2794  2025-02-06   Team_Invite            3
# 16688  USG_716689   CUST_2671  2025-07-31    Export_Csv            2
#
#        session_minutes
# 19126           115.74
# 13022            42.57
# 11480            82.05
# 16951            51.29
# 17417            35.74
# 4552             64.55
# 15025             9.00
# ...

# %%
usage.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 22702 entries, 0 to 24755
# Data columns (total 6 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   usage_id         22702 non-null  object
#  1   customer_id      22702 non-null  object
#  2   event_date       22702 non-null  object
#  3   feature_name     22702 non-null  object
#  4   login_count      22702 non-null  int64
#  5   session_minutes  22702 non-null  float64
# dtypes: float64(1), int64(1), object(4)
# memory usage: 1.2+ MB

# %%
usage['event_date']=pd.to_datetime(usage['event_date'],errors='coerce')

# %%
usage.columns=usage.columns.str.title()

# %%
usage.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 22702 entries, 0 to 24755
# Data columns (total 6 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Usage_Id         22702 non-null  object
#  1   Customer_Id      22702 non-null  object
#  2   Event_Date       22702 non-null  datetime64[ns]
#  3   Feature_Name     22702 non-null  object
#  4   Login_Count      22702 non-null  int64
#  5   Session_Minutes  22702 non-null  float64
# dtypes: datetime64[ns](1), float64(1), int64(1), object(3)
# memory usage: 1.2+ MB

# %%
usage.sample(5)
# Out:
#          Usage_Id Customer_Id Event_Date Feature_Name  Login_Count  \
# 23675  USG_723676   CUST_2954 2025-12-15  Team_Invite            4
# 7453   USG_707454   CUST_2303 2025-03-21   Export_Csv            8
# 8257   USG_708258   CUST_2333 2025-07-21  Team_Invite            5
# 2920   USG_702921   CUST_2118 2025-07-28  Team_Invite            1
# 21058  USG_721059   CUST_2846 2025-03-17   Export_Csv            7
#
#        Session_Minutes
# 23675            19.53
# 7453            109.97
# 8257             16.35
# 2920              6.66
# 21058            71.53

# %%
usage_clean=usage.copy()

# %%
usage_clean.to_csv('usage_clean.csv',index=False)

# %%
usage_clean
# Out:
#          Usage_Id Customer_Id Event_Date    Feature_Name  Login_Count  \
# 0      USG_700001   CUST_2000 2025-09-08  Dashboard_View            8
# 1      USG_700002   CUST_2000 2025-05-11      Export_Csv            3
# 2      USG_700003   CUST_2000 2025-01-17      Export_Csv            3
# 3      USG_700004   CUST_2000 2025-03-10      Export_Csv            8
# 4      USG_700005   CUST_2000 2025-05-25      Export_Csv            3
# ...           ...         ...        ...             ...          ...
# 24751  USG_724752   CUST_2999 2025-01-20     Team_Invite            1
# 24752  USG_724753   CUST_2999 2025-01-14      Export_Csv            5
# 24753  USG_724754   CUST_2999 2025-05-20     Team_Invite            5
# 24754  USG_724755   CUST_2999 2025-10-25      Export_Csv            8
# 24755  USG_724756   CUST_2999 2025-01-10    Billing_Edit            3
#
#        Session_Minutes
# 0               114.76
# 1                44.68
# 2                76.59
# 3                58.81
# ...

# %% [markdown]
# # 6. Support Dataset

# %% [markdown]
# ## Data Inspection

# %%
support
# Out:
#       ticket_id customer_id ticket_date  priority         category  \
# 0    TCK_900001   CUST_2006  2025-02-17      HIGH      Login Issue
# 1    TCK_900002   CUST_2006  2025-07-17       LOW         API Down
# 2    TCK_900003   CUST_2007  2025-08-23       LOW      Login Issue
# 3    TCK_900004   CUST_2008  2025-11-10    MEDIUM      Login Issue
# 4    TCK_900005   CUST_2008  2025-07-22    MEDIUM  Feature Request
# ..          ...         ...         ...       ...              ...
# 779  TCK_900780   CUST_3491  2025-07-02    MEDIUM  Feature Request
# 780  TCK_900781   CUST_3491  2025-03-02      HIGH         API Down
# 781  TCK_900782   CUST_3496  2025-04-09    MEDIUM  Feature Request
# 782  TCK_900783   CUST_3496  2025-08-07       LOW      Login Issue
# 783  TCK_900784   CUST_3496  2025-07-08  CRITICAL         API Down
#
#      resolution_time    status
# 0                 12    Closed
# 1                 41  resolved
# 2                 21    Closed
# 3                 43  resolved
# ...

# %%
support.shape
# Out:
# (784, 7)

# %%
support.columns
# Out:
# Index(['ticket_id', 'customer_id', 'ticket_date', 'priority', 'category',
#        'resolution_time', 'status'],
#       dtype='object')

# %%
support.dtypes
# Out:
# ticket_id          object
# customer_id        object
# ticket_date        object
# priority           object
# category           object
# resolution_time     int64
# status             object
# dtype: object

# %%
support.head()
# Out:
#     ticket_id customer_id ticket_date priority         category  \
# 0  TCK_900001   CUST_2006  2025-02-17     HIGH      Login Issue
# 1  TCK_900002   CUST_2006  2025-07-17      LOW         API Down
# 2  TCK_900003   CUST_2007  2025-08-23      LOW      Login Issue
# 3  TCK_900004   CUST_2008  2025-11-10   MEDIUM      Login Issue
# 4  TCK_900005   CUST_2008  2025-07-22   MEDIUM  Feature Request
#
#    resolution_time    status
# 0               12    Closed
# 1               41  resolved
# 2               21    Closed
# 3               43  resolved
# 4                1  resolved

# %%
support.tail()
# Out:
#       ticket_id customer_id ticket_date  priority         category  \
# 779  TCK_900780   CUST_3491  2025-07-02    MEDIUM  Feature Request
# 780  TCK_900781   CUST_3491  2025-03-02      HIGH         API Down
# 781  TCK_900782   CUST_3496  2025-04-09    MEDIUM  Feature Request
# 782  TCK_900783   CUST_3496  2025-08-07       LOW      Login Issue
# 783  TCK_900784   CUST_3496  2025-07-08  CRITICAL         API Down
#
#      resolution_time    status
# 779                8  resolved
# 780               19      open
# 781               64  resolved
# 782               60    Closed
# 783               65  resolved

# %%
support.sample(5)
# Out:
#       ticket_id customer_id ticket_date priority         category  \
# 495  TCK_900496   CUST_2950  2025-07-09      LOW      Login Issue
# 447  TCK_900448   CUST_2838  2025-03-08   MEDIUM         API Down
# 360  TCK_900361   CUST_2670  2025-05-04     HIGH         API Down
# 226  TCK_900227   CUST_2450  2025-09-27   MEDIUM         API Down
# 143  TCK_900144   CUST_2293  2025-11-25      LOW  Feature Request
#
#      resolution_time    status
# 495               54      open
# 447               26  resolved
# 360               26      open
# 226               41  resolved
# 143               31    Closed

# %%
support.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 784 entries, 0 to 783
# Data columns (total 7 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   ticket_id        784 non-null    object
#  1   customer_id      784 non-null    object
#  2   ticket_date      784 non-null    object
#  3   priority         784 non-null    object
#  4   category         784 non-null    object
#  5   resolution_time  784 non-null    int64
#  6   status           784 non-null    object
# dtypes: int64(1), object(6)
# memory usage: 43.0+ KB

# %%
support.describe(include='all')
# Out:
#          ticket_id customer_id ticket_date priority  category  \
# count          784         784         784      784       784
# unique         784         379         294        4         4
# top     TCK_900784   CUST_2136  2025-02-23     HIGH  API Down
# freq             1           3          11      206       214
# mean           NaN         NaN         NaN      NaN       NaN
# std            NaN         NaN         NaN      NaN       NaN
# min            NaN         NaN         NaN      NaN       NaN
# 25%            NaN         NaN         NaN      NaN       NaN
# 50%            NaN         NaN         NaN      NaN       NaN
# 75%            NaN         NaN         NaN      NaN       NaN
# max            NaN         NaN         NaN      NaN       NaN
#
#         resolution_time  status
# count        784.000000     784
# unique              NaN       3
# top                 NaN  Closed
# freq                NaN     270
# mean          36.206633     NaN
# ...

# %% [markdown]
# ## Data Quality

# %%
support.isnull().sum()
# Out:
# ticket_id          0
# customer_id        0
# ticket_date        0
# priority           0
# category           0
# resolution_time    0
# status             0
# dtype: int64

# %%
support.duplicated().sum()
# Out:
# np.int64(0)

# %%
support['ticket_id'].isnull().sum()
# Out:
# np.int64(0)

# %%
support['ticket_id'].duplicated().sum()
# Out:
# np.int64(0)

# %%
support[ ~support["customer_id"].isin(customers["Customer_Id"])]
# Out:
#       ticket_id customer_id ticket_date  priority         category  \
# 13   TCK_900014   CUST_2043  2025-05-13       LOW         API Down
# 14   TCK_900015   CUST_2043  2025-06-07       LOW         API Down
# 48   TCK_900049   CUST_2142  2025-11-25  CRITICAL      Billing Bug
# 49   TCK_900050   CUST_2142  2025-02-03    MEDIUM  Feature Request
# 50   TCK_900051   CUST_2142  2025-07-16      HIGH      Login Issue
# 67   TCK_900068   CUST_2181  2025-04-06  CRITICAL      Login Issue
# 68   TCK_900069   CUST_2181  2025-08-22       LOW      Login Issue
# 69   TCK_900070   CUST_2181  2025-11-27  CRITICAL      Billing Bug
# 127  TCK_900128   CUST_2274  2025-06-26      HIGH  Feature Request
# 128  TCK_900129   CUST_2274  2025-10-25      HIGH      Login Issue
# 174  TCK_900175   CUST_2350  2025-05-31    MEDIUM  Feature Request
# 175  TCK_900176   CUST_2350  2025-07-02    MEDIUM      Login Issue
# 176  TCK_900177   CUST_2350  2025-08-08      HIGH         API Down
# ...

# %%
len(support[ ~support["customer_id"].isin(customers["Customer_Id"])])
# Out:
# 68

# %%
support['customer_id'].isnull().sum()
# Out:
# np.int64(0)

# %%
support['priority'].unique()
# Out:
# array(['HIGH', 'LOW', 'MEDIUM', 'CRITICAL'], dtype=object)

# %%
support['priority'].value_counts(dropna=False)
# Out:
# priority
# HIGH        206
# LOW         199
# CRITICAL    194
# MEDIUM      185
# Name: count, dtype: int64

# %%
support['category'].unique()
# Out:
# array(['Login Issue', 'API Down', 'Feature Request', 'Billing Bug'],
#       dtype=object)

# %%
support['category'].value_counts()
# Out:
# category
# API Down           214
# Billing Bug        197
# Login Issue        192
# Feature Request    181
# Name: count, dtype: int64

# %%
support['status'].unique()
# Out:
# array(['Closed', 'resolved', 'open'], dtype=object)

# %%
support['status'].value_counts(dropna=False)
# Out:
# status
# Closed      270
# resolved    261
# open        253
# Name: count, dtype: int64

# %%
support[support['resolution_time']<0]
# Out:
# Empty DataFrame
# Columns: [ticket_id, customer_id, ticket_date, priority, category, resolution_time, status]
# Index: []

# %%
(support['resolution_time']<0).sum()
# Out:
# np.int64(0)

# %% [markdown]
# ## Data Cleaning

# %%
support = support[support["customer_id"].isin(customers["Customer_Id"])].copy()

# %%
support[~support['customer_id'].isin(customers['Customer_Id'])]
# Out:
# Empty DataFrame
# Columns: [ticket_id, customer_id, ticket_date, priority, category, resolution_time, status]
# Index: []

# %%
support['ticket_date']=pd.to_datetime(support['ticket_date'],errors='coerce')

# %%
support.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 716 entries, 0 to 783
# Data columns (total 7 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   ticket_id        716 non-null    object
#  1   customer_id      716 non-null    object
#  2   ticket_date      716 non-null    datetime64[ns]
#  3   priority         716 non-null    object
#  4   category         716 non-null    object
#  5   resolution_time  716 non-null    int64
#  6   status           716 non-null    object
# dtypes: datetime64[ns](1), int64(1), object(5)
# memory usage: 44.8+ KB

# %%
support['ticket_date'].min()
# Out:
# Timestamp('2025-01-31 00:00:00')

# %%
support['ticket_date'].max()
# Out:
# Timestamp('2025-12-17 00:00:00')

# %%
support['priority']=support['priority'].str.title()

# %%
support['priority'].value_counts()
# Out:
# priority
# High        191
# Low         183
# Critical    178
# Medium      164
# Name: count, dtype: int64

# %%
support['status']=support['status'].str.title()

# %%
support['status'].value_counts()
# Out:
# status
# Closed      246
# Resolved    242
# Open        228
# Name: count, dtype: int64

# %%
support.columns=support.columns.str.title()

# %%
support
# Out:
#       Ticket_Id Customer_Id Ticket_Date  Priority         Category  \
# 0    TCK_900001   CUST_2006  2025-02-17      High      Login Issue
# 1    TCK_900002   CUST_2006  2025-07-17       Low         API Down
# 2    TCK_900003   CUST_2007  2025-08-23       Low      Login Issue
# 3    TCK_900004   CUST_2008  2025-11-10    Medium      Login Issue
# 4    TCK_900005   CUST_2008  2025-07-22    Medium  Feature Request
# ..          ...         ...         ...       ...              ...
# 779  TCK_900780   CUST_3491  2025-07-02    Medium  Feature Request
# 780  TCK_900781   CUST_3491  2025-03-02      High         API Down
# 781  TCK_900782   CUST_3496  2025-04-09    Medium  Feature Request
# 782  TCK_900783   CUST_3496  2025-08-07       Low      Login Issue
# 783  TCK_900784   CUST_3496  2025-07-08  Critical         API Down
#
#      Resolution_Time    Status
# 0                 12    Closed
# 1                 41  Resolved
# 2                 21    Closed
# 3                 43  Resolved
# ...

# %%
support_clean=support.copy()

# %%
support_clean
# Out:
#       Ticket_Id Customer_Id Ticket_Date  Priority         Category  \
# 0    TCK_900001   CUST_2006  2025-02-17      High      Login Issue
# 1    TCK_900002   CUST_2006  2025-07-17       Low         API Down
# 2    TCK_900003   CUST_2007  2025-08-23       Low      Login Issue
# 3    TCK_900004   CUST_2008  2025-11-10    Medium      Login Issue
# 4    TCK_900005   CUST_2008  2025-07-22    Medium  Feature Request
# ..          ...         ...         ...       ...              ...
# 779  TCK_900780   CUST_3491  2025-07-02    Medium  Feature Request
# 780  TCK_900781   CUST_3491  2025-03-02      High         API Down
# 781  TCK_900782   CUST_3496  2025-04-09    Medium  Feature Request
# 782  TCK_900783   CUST_3496  2025-08-07       Low      Login Issue
# 783  TCK_900784   CUST_3496  2025-07-08  Critical         API Down
#
#      Resolution_Time    Status
# 0                 12    Closed
# 1                 41  Resolved
# 2                 21    Closed
# 3                 43  Resolved
# ...

# %% [raw]
# support_clean=support.copy()

# %%
support_clean
# Out:
#       Ticket_Id Customer_Id Ticket_Date  Priority         Category  \
# 0    TCK_900001   CUST_2006  2025-02-17      High      Login Issue
# 1    TCK_900002   CUST_2006  2025-07-17       Low         API Down
# 2    TCK_900003   CUST_2007  2025-08-23       Low      Login Issue
# 3    TCK_900004   CUST_2008  2025-11-10    Medium      Login Issue
# 4    TCK_900005   CUST_2008  2025-07-22    Medium  Feature Request
# ..          ...         ...         ...       ...              ...
# 779  TCK_900780   CUST_3491  2025-07-02    Medium  Feature Request
# 780  TCK_900781   CUST_3491  2025-03-02      High         API Down
# 781  TCK_900782   CUST_3496  2025-04-09    Medium  Feature Request
# 782  TCK_900783   CUST_3496  2025-08-07       Low      Login Issue
# 783  TCK_900784   CUST_3496  2025-07-08  Critical         API Down
#
#      Resolution_Time    Status
# 0                 12    Closed
# 1                 41  Resolved
# 2                 21    Closed
# 3                 43  Resolved
# ...

# %%
support_clean.to_csv('support_clean.csv',index=False)

# %% [markdown]
# # Conclusion
# The datasets have been successfully cleaned and validated. Data quality issues such as missing values, duplicate records, inconsistent values, incorrect data types, and relationship mismatches were resolved.
#
# These cleaned datasets are now ready for exploratory data analysis, SQL-based business analysis, and dashboard development.
